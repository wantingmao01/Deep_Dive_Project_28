# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def getfile(location_pair,**kwargs): #tries to get local version and then defaults to google drive version
    (loc,gdrive)=location_pair
    try:
        out=pd.read_csv(loc,**kwargs)
    except FileNotFoundError:
        print("local file not found; accessing Google Drive")
        loc = 'https://drive.google.com/uc?export=download&id='+gdrive.split('/')[-2]
        out=pd.read_csv(loc,**kwargs)
    return out

# %%
fname=("uiuc-gpa-dataset.csv","https://drive.google.com/file/d/1-NkhQzXPhPfrLvhmGuyfuu9gHAiDDLpa/view?usp=sharing")
data=getfile(fname)
data.head()
# Out:
# local file not found; accessing Google Drive
#    Year    Term YearTerm Subject  Number                  Course Title  \
# 0  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 1  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 2  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 3  2023  Spring  2023-sp     AAS     200          U.S. Race and Empire
# 4  2023  Spring  2023-sp     AAS     215  US Citizenship Comparatively
#
#   Sched Type  A+   A  A-  ...  B-  C+  C  C-  D+  D  D-  F  W  \
# 0        DIS   0  11   5  ...   0   0  0   0   0  0   0  1  0
# 1        DIS   0  17   2  ...   1   0  0   0   0  0   0  0  1
# 2        DIS   0  13   2  ...   2   0  0   1   0  0   0  1  0
# 3        LCD   6  15   5  ...   0   0  0   0   0  1   0  1  0
# 4        LCD  16  12   2  ...   1   0  0   0   0  0   0  0  0
#
#    Primary Instructor
# 0       Shin, Jeongsu
# 1       Shin, Jeongsu
# 2      Lee, Sabrina Y
# 3      Sawada, Emilia
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Term', 'YearTerm', 'Subject', 'Number', 'Course Title',
#        'Sched Type', 'A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+',
#        'D', 'D-', 'F', 'W', 'Primary Instructor'],
#       dtype='object')

# %% [markdown]
# Calculate average gpa of each course.

# %%
data["Class Size"] = data['A+'] + data['A'] + data['A-'] + data['B+'] + data['B'] + data['B-'] + data['C+'] + data['C'] + data['C-'] + data['D+'] + data['D'] + data['D-'] + data['F'] # W is not included as it does not affect GPA
data["Average GPA"] = (data['A+']*4 + data['A']*4 + data['A-']*3.67 + data['B+']*3.33 + data['B']*3 + data['B-']*2.67 + data['C+']*2.33 + data['C']*2.00 + data['C-']*1.67 + data['D+']*1.33 + data['D'] + data['D-']*0.67) / data["Class Size"]

# %%
data.head()
# Out:
#    Year    Term YearTerm Subject  Number                  Course Title  \
# 0  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 1  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 2  2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 3  2023  Spring  2023-sp     AAS     200          U.S. Race and Empire
# 4  2023  Spring  2023-sp     AAS     215  US Citizenship Comparatively
#
#   Sched Type  A+   A  A-  ...  C  C-  D+  D  D-  F  W  Primary Instructor  \
# 0        DIS   0  11   5  ...  0   0   0  0   0  1  0       Shin, Jeongsu
# 1        DIS   0  17   2  ...  0   0   0  0   0  0  1       Shin, Jeongsu
# 2        DIS   0  13   2  ...  0   1   0  0   0  1  0      Lee, Sabrina Y
# 3        LCD   6  15   5  ...  0   0   0  1   0  1  0      Sawada, Emilia
# 4        LCD  16  12   2  ...  0   0   0  0   0  0  0        Kwon, Soo Ah
#
#    Class Size  Average GPA
# 0          22     3.530909
# 1          23     3.797391
# ...

# %% [markdown]
# # Debugging Dataset
# small enough to test code with; reasonable code should run in 2 minutes

# %%
debug_data = data.sample(n=5000, random_state=42)  # Adjust 'n' for desired size
debug_data.shape
# Out:
# (5000, 24)

# %% [markdown]
# # Working Dataset
# large enough to do the problem on (training should run no more than 40 minutes)

# %%
working_data = data
working_data.shape
# Out:
# (69069, 24)

# %% [markdown]
# # Convert these datasets to pandas
# - I suggest that you convert datetime to pandas timestamps (allows for time deltas and time manipulation)
# - Pickle (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_pickle.html)  the data.  That converts it to a binary file which can be loaded directly (must faster) into the correct datatypes

# %%
# Pickle the dataframes
working_data.to_pickle('working_data.pkl')
debug_data.to_pickle('debug_data.pkl')
